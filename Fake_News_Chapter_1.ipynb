# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul21388/Fake-News-Detection/blob/main/Fake_News_Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.1: Import the necessary libraries for data manipulation
import pandas as pd

# 1.2: Mount Google Drive to access CSV files stored there
from google.colab import drive
drive.mount('/content/drive')

# 1.3: Load the True and Fake news datasets from Google Drive
true_df = pd.read_csv("/content/drive/MyDrive/True.csv")
fake_df = pd.read_csv("/content/drive/MyDrive/Fake.csv")

# 1.4: Add a new column 'news_label' to the true and fake DataFrames
true_df['news_label'] = 1
fake_df['news_label'] = 0

# 1.5: Combine the true and fake news DataFrames into a single DataFrame
combined_df = pd.concat([true_df, fake_df], ignore_index=True)

# 1.6: Display the first 5 rows of the combined DataFrame to verify the result
combined_df.head()

# 1.7: Check Presence of Null Values
combined_df.isnull().sum()

# 1.8: Handle Rows with Null Values
combined_df.dropna(inplace=True)

# 1.9: Combine the relevant columns into a new column 'news_text' by joining their values with a space
#      Drop the irrelevant columns from the DataFrame as they are no longer needed
#      Display the first 5 rows of the updated DataFrame to check the result
combined_df['news_text'] = combined_df['title'] + " " + combined_df['text']
combined_df.drop(columns=['title', 'text', 'date'], inplace=True)
combined_df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    news_label                                          news_text
# 0           1  As U.S. budget fight looms, Republicans flip t...
# 1           1  U.S. military to accept transgender recruits o...
# 2           1  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3           1  FBI Russia probe helped by Australian diplomat...
# 4           1  Trump wants Postal Service to charge 'much mor...
